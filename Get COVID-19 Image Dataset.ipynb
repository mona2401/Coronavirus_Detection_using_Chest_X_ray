# %%
import numpy as np
import pandas as pd
covid_data=pd.read_csv('C:\\Users\\hp\\Downloads\\covid-chest-xray\\metadata.csv')
covid_data.head()
# Out:
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
# 2          2     5.0   M  65.0  COVID-19        Y       NaN
# 3          2     6.0   M  65.0  COVID-19        Y       NaN
# 4          4     0.0   F  52.0  COVID-19      NaN       NaN
#
#   intubation_present went_icu needed_supplemental_O2  ...              date  \
# 0                NaN      NaN                    NaN  ...  January 22, 2020
# 1                NaN      NaN                    NaN  ...  January 25, 2020
# 2                NaN      NaN                    NaN  ...  January 27, 2020
# 3                NaN      NaN                    NaN  ...  January 28, 2020
# 4                NaN      NaN                    NaN  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
covid_data.dropna(axis=1,inplace=True)
covid_data.head()
# Out:
#    patientid   finding view modality  folder  \
# 0          2  COVID-19   PA    X-ray  images
# 1          2  COVID-19   PA    X-ray  images
# 2          2  COVID-19   PA    X-ray  images
# 3          2  COVID-19   PA    X-ray  images
# 4          4  COVID-19   PA    X-ray  images
#
#                                             filename  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...
# 4                              nejmc2001573_f1a.jpeg
#
#                                                  url
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...

# %%
covid_data.groupby('finding').count()
# Out:
#                 patientid  view  modality  folder  filename  url
# finding
# ARDS                    4     4         4       4         4    4
# COVID-19              253   253       253     253       253  253
# COVID-19, ARDS         12    12        12      12        12   12
# Chlamydophila           2     2         2       2         2    2
# E.Coli                  4     4         4       4         4    4
# Klebsiella              1     1         1       1         1    1
# Legionella              2     2         2       2         2    2
# No Finding              3     3         3       3         3    3
# Pneumocystis           15    15        15      15        15   15
# SARS                   16    16        16      16        16   16
# Streptococcus          17    17        17      17        17   17

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
coronavirus = "COVID-19" # Virus to look for
x_ray = "PA" # View of X-Ray

metadata = "C:\\Users\\hp\\Downloads\\covid-chest-xray\\metadata.csv" # Metadata.csv Directory
imageDir = "C:\\Users\\hp\\Downloads\\covid-chest-xray\\images" # Directory of images
outputDir = 'C://Users//hp//Desktop//Data//Covid' # Output directory to store selected images

metadata_csv = pd.read_csv(metadata)

# loop over the rows of the COVID-19 data frame
for (i, row) in metadata_csv.iterrows():
    if row["finding"] != coronavirus or row["view"] != x_ray:
        continue

    filename = row['filename'].split(os.path.sep)[-1]
    filePath = os.path.sep.join([imageDir, filename])
    shutil.copy2(filePath, outputDir)
print('Done')
# Out:
# Done
